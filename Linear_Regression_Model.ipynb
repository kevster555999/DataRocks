# %%
using DataFrames,Gadfly

# %%
images = readtable("training_data.csv")
test = readtable("test_data.csv")
# Out:
# 1228×402 DataFrames.DataFrame
# │ Row  │ File │ Value │ x1  │ x2  │ x3  │ x4  │ x5  │ x6  │ x7  │ x8  │ x9  │
# ├──────┼──────┼───────┼─────┼─────┼─────┼─────┼─────┼─────┼─────┼─────┼─────┤
# │ 1    │ 100  │ "Z"   │ 222 │ 222 │ 222 │ 222 │ 222 │ 221 │ 220 │ 220 │ 219 │
# │ 2    │ 1015 │ "A"   │ 109 │ 107 │ 108 │ 104 │ 108 │ 108 │ 105 │ 106 │ 106 │
# │ 3    │ 1019 │ "l"   │ 24  │ 27  │ 24  │ 21  │ 22  │ 22  │ 22  │ 23  │ 22  │
# │ 4    │ 1027 │ "o"   │ 66  │ 70  │ 63  │ 66  │ 63  │ 66  │ 67  │ 66  │ 66  │
# │ 5    │ 1032 │ "r"   │ 157 │ 158 │ 158 │ 154 │ 154 │ 162 │ 157 │ 152 │ 159 │
# │ 6    │ 1035 │ "V"   │ 10  │ 8   │ 9   │ 8   │ 13  │ 8   │ 8   │ 12  │ 10  │
# │ 7    │ 104  │ "5"   │ 63  │ 64  │ 67  │ 59  │ 60  │ 66  │ 69  │ 71  │ 73  │
# │ 8    │ 1046 │ "d"   │ 120 │ 125 │ 125 │ 123 │ 114 │ 130 │ 134 │ 126 │ 113 │
# │ 9    │ 1048 │ "4"   │ 154 │ 174 │ 172 │ 171 │ 173 │ 174 │ 174 │ 173 │ 173 │
# │ 10   │ 1056 │ "4"   │ 150 │ 150 │ 150 │ 151 │ 151 │ 150 │ 149 │ 152 │ 151 │
# ...

# %%
y=[images[:File] images[:Value]]
# Out:
# 5055×2 DataArrays.DataArray{Any,2}:
#     1  "n"
#    10  "G"
#  1000  "E"
#  1001  "r"
#  1002  "T"
#  1003  "n"
#  1004  "n"
#  1005  "A"
#  1006  "r"
#  1007  "E"
#  1008  "A"
#  1009  "0"
#   101  "D"
#     ⋮
#   986  "P"
#   987  "C"
#   988  "A"
#   989  "T"
#    99  "r"
#   990  "4"
#   994  "e"
#   995  "G"
#   996  "J"
#   997  "e"
#   998  "N"
#   999  "e"
